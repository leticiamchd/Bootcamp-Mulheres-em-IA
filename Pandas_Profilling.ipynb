# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiamchd/Bootcamp-Mulheres-em-IA/blob/main/Pandas_Profilling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Primeiro tem que instalar 
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip -q
# Out:
#      \ 21.9 MB 56 kB/s
#      |████████████████████████████████| 102 kB 29.6 MB/s
#      |████████████████████████████████| 690 kB 50.3 MB/s
#      |████████████████████████████████| 4.7 MB 51.2 MB/s
#      |████████████████████████████████| 62 kB 401 kB/s
#      |████████████████████████████████| 812 kB 63.3 MB/s
# ...

# %%
import pandas as pd
from pandas_profiling import ProfileReport

# %%
# Utilizei como exemplo o dataset de uma das aulas
df = pd.read_csv("https://raw.githubusercontent.com/mulheres-em-ia/bootcamp-mia-2022/main/6.%20Classifica%C3%A7%C3%A3o%201/heart_failure_predict.csv")

# %%
df.head()

# %%
# criar ProfileReport
report = ProfileReport(df)

# %%
# criar visualização iframe
report.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# criar relatório html
report.to_file("report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ![Captura de Tela (102).png](data:image/png;base64,...)

# %% [markdown]
# **Aí fica disponível para fazer o download**
